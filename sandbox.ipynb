# %%
from modelo import CotizacionHistorica
from datetime import date
historico = CotizacionHistorica("data/aapl_5y.csv")
df = historico.cotizaciones(date(2020, 6, 12), date(2025, 6, 12))
df.head()
# Out:
#         Date  Close/Last    Volume    Open    High       Low  \
# 0 2025-06-12      199.20  43904640  199.08  199.68  197.3601
# 1 2025-06-11      198.78  60989860  203.50  204.50  198.4100
# 2 2025-06-10      202.67  54672610  200.60  204.35  200.5700
# 3 2025-06-09      201.45  72862560  204.39  206.00  200.0200
# 4 2025-06-06      203.92  46607690  203.00  205.70  202.0500
#
#    Diff_Apertura_Cierre  Diff_Max_Min   Año  Mes
# 0                 -0.12        2.3199  2025    6
# 1                  4.72        6.0900  2025    6
# 2                 -2.07        3.7800  2025    6
# 3                  2.94        5.9800  2025    6
# 4                 -0.92        3.6500  2025    6

# %%
historico.por_mes_anio()
# Out:
# /home/nadia/dev/unsl-bayes-stock/modelo.py:24: FutureWarning: The provided callable <function mean at 0x741658bbc5e0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ["Año", "Mes"]).agg([np.mean, np.std])
# /home/nadia/dev/unsl-bayes-stock/modelo.py:24: FutureWarning: The provided callable <function std at 0x741658bbc700> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   ["Año", "Mes"]).agg([np.mean, np.std])
#          Diff_Apertura_Cierre
#                          mean       std
# Año  Mes
# 2020 6              -0.290317  1.566506
#      7              -0.145632  1.722276
#      8              -0.329990  2.018297
#      9               0.954048  3.349827
#      10              0.280909  2.342010
# ...

# %%
from graficos import GraficosCotizaciones

g = GraficosCotizaciones(historico)
g.diferencias_cierre_apertura()

# %%
g.diferencias_max_min()

# %%
g.aperturas()

# %%
g.ultimos_cierres()

# %%
g.minimos()

# %%
g.maximos()

# %%
print(historico.fecha_min(), historico.fecha_max())
# Out:
# 2020-06-15 00:00:00 2025-06-12 00:00:00

# %%
g.diferencias_cierre_apertura(fecha_hasta=date(2024,6,12))

# %%
g.diferencias_cierre_apertura(fecha_desde=date(2024, 6, 13), fecha_hasta=date(2025,6,12))

# %%
df=historico.cotizaciones(historico.fecha_min(), historico.fecha_max())
df["Año"] =
# Out:
# -0.1561102707006368
# 2.5545468207508693
